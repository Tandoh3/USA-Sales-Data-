# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Documents'

# %%
os.chdir('C:\\Users\\hp\\Dropbox\\My PC (Tandoh)\\Documents\\Tableau')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Dropbox\\My PC (Tandoh)\\Documents\\Tableau'

# %%
import pandas as pd 
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
sales = pd.read_csv('train.csv')
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
sales.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
sales.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
pd.DataFrame(sales['Postal Code'])
# Out:
#       Postal Code
# 0         42420.0
# 1         42420.0
# 2         90036.0
# 3         33311.0
# 4         33311.0
# ...           ...
# 9795      60610.0
# 9796      43615.0
# 9797      43615.0
# 9798      43615.0
# 9799      43615.0
#
# [9800 rows x 1 columns]

# %%
sales[sales["Postal Code"].isna()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
sales.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
sales['Postal Code'] = sales['Postal Code'].fillna(5401)

# %%
sns.heatmap(sales.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sales.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Row ID'}>,
#         <AxesSubplot:title={'center':'Postal Code'}>],
#        [<AxesSubplot:title={'center':'Sales'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sales.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
#first 6 orders 
sales_order = sales[['Order ID', 'Customer Name','Product ID', 'Product Name','Sales']]
sales_order.head(6)
# Out:
#          Order ID    Customer Name       Product ID  \
# 0  CA-2017-152156      Claire Gute  FUR-BO-10001798
# 1  CA-2017-152156      Claire Gute  FUR-CH-10000454
# 2  CA-2017-138688  Darrin Van Huff  OFF-LA-10000240
# 3  US-2016-108966   Sean O'Donnell  FUR-TA-10000577
# 4  US-2016-108966   Sean O'Donnell  OFF-ST-10000760
# 5  CA-2015-115812  Brosina Hoffman  FUR-FU-10001487
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600

# %%
#last 6 orders 
sales_order = sales[['Order ID', 'Customer Name','Product ID', 'Product Name','Sales']]
sales_order.tail(6)
# Out:
#             Order ID     Customer Name       Product ID  \
# 9794  CA-2015-127166  Katherine Hughes  OFF-BI-10000977
# 9795  CA-2017-125920     Sally Hughsby  OFF-BI-10003429
# 9796  CA-2016-128608  Cindy Schnelling  OFF-AR-10001374
# 9797  CA-2016-128608  Cindy Schnelling  TEC-PH-10004977
# 9798  CA-2016-128608  Cindy Schnelling  TEC-PH-10000912
# 9799  CA-2016-128608  Cindy Schnelling  TEC-AC-10000487
#
#                                            Product Name    Sales
# 9794                 Ibico Plastic Spiral Binding Combs   18.240
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.798
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.368
# 9797                                        GE 30524EE4  235.188
# 9798           Anker 24W Portable Micro USB Car Charger   26.376
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.384

# %%
sales_order = sales[['Order ID', 'Customer Name','Product ID', 'Product Name','Sales']].shape
sales_order
# Out:
# (9800, 5)

# %%
customer_type = sales['Segment'].value_counts()
customer_type
# Out:
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: Segment, dtype: int64

# %%
#Home office and Corporation orders 
customer_type_segregation = sales[sales['Segment'].isin(['Home Office','Corporate'])]
customer_type_segregation
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 14        15  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# 15        16  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# 21        22  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# 22        23  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# ...

# %%
customer_type_segregation2 = sales[(sales['Segment']=='Home Office') | (sales['Segment']=='Corporate')]
customer_type_segregation2
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 14        15  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# 15        16  US-2016-118983  22/11/2016  26/11/2016  Standard Class
# 21        22  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# 22        23  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# ...

# %%
#filtering out the data 
#sales above 5000
sales_above_5000 = sales[sales['Sales']>5000]
sales_above_5000
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 165      166  CA-2015-139892  08/09/2015  12/09/2015  Standard Class
# 509      510  CA-2016-145352  16/03/2016  22/03/2016  Standard Class
# 683      684  US-2018-168116  04/11/2018  04/11/2018        Same Day
# 2505    2506  CA-2015-143917  25/07/2015  27/07/2015    Second Class
# 2623    2624  CA-2018-127180  22/10/2018  24/10/2018     First Class
# 2697    2698  CA-2015-145317  18/03/2015  23/03/2015  Standard Class
# 4098    4099  CA-2015-116904  23/09/2015  28/09/2015  Standard Class
# 4190    4191  CA-2018-166709  17/11/2018  22/11/2018  Standard Class
# 4277    4278  US-2017-107440  16/04/2017  20/04/2017  Standard Class
# 6340    6341  CA-2018-143112  05/10/2018  09/10/2018  Standard Class
# 6425    6426  CA-2017-143714  23/05/2017  27/05/2017  Standard Class
# 6520    6521  CA-2018-138289  16/01/2018  18/01/2018    Second Class
# 6626    6627  CA-2015-145541  14/12/2015  21/12/2015  Standard Class
# ...

# %%
sales_above_5000 = sales[sales['Sales']>5000].count()
sales_above_5000
# Out:
# Row ID           19
# Order ID         19
# Order Date       19
# Ship Date        19
# Ship Mode        19
# Customer ID      19
# Customer Name    19
# Segment          19
# Country          19
# City             19
# State            19
# Postal Code      19
# Region           19
# Product ID       19
# Category         19
# Sub-Category     19
# Product Name     19
# Sales            19
# dtype: int64

# %%
# %whos
# Out:
# Variable                     Type         Data/Info
# ---------------------------------------------------
# customer_type                Series       Consumer       5101\nCorp<...>me: Segment, dtype: int64
# customer_type_segregation    DataFrame          Row ID        Order<...>n[4699 rows x 18 columns]
# customer_type_segregation2   DataFrame          Row ID        Order<...>n[4699 rows x 18 columns]
# os                           module       <module 'os' from 'c:\\py<...>\\python391\\lib\\os.py'>
# pd                           module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# sales                        DataFrame          Row ID        Order<...>n[9800 rows x 18 columns]
# sales_above_5000             Series       Row ID           19\nOrde<...>         19\ndtype: int64
# sales_order                  tuple        n=2
# sns                          module       <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>

# %%
Postal_Code_notNa = sales[sales['Postal Code'].notna()]
Postal_Code_notNa
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
Postal_Code_notNa.shape
# Out:
# (9789, 18)
